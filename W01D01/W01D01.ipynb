# %%
print('Hello we are learning python')
# Out:
# Hello we are learning python

# %%
# Basic syntax and data types

# %%
list_of_fruits = ['apple', 'mango', 'banana', 'kiwi']


vitamin_c_fruit = ['kiwi', 'orange']


for fruit in list_of_fruits:
    if fruit in vitamin_c_fruit:
        print(f'{fruit} contains Vitamin C')
    else:
        print(f'{fruit} does not contain Vitamin C')
    print('this is outside the previous else block but inside for loop')
print('We are out of the loop!!')
# Out:
# apple does not contain Vitamin C
# this is outside the previous else block but inside for loop
# mango does not contain Vitamin C
# this is outside the previous else block but inside for loop
# banana does not contain Vitamin C
# this is outside the previous else block but inside for loop
# kiwi contains Vitamin C
# this is outside the previous else block but inside for loop
# We are out of the loop!!

# %%
# Input/Output Operations and Comment.

x = input('Write something')
# Out:
# Write something56

# %%
x
# Out:
# '56'

# %%
x = input()
# Out:
# 78

# %%
x
# Out:
# '78'

# %%
print('Happy Holidays')
# Out:
# Happy Holidays

# %%
# This is a comment which python will ignore.

print('This is an actual code')
# Out:
# This is an actual code

# %%
f"{x} is something"
# Out:
# '78 is something'

# %%
# Data Types:-

# When to use which data type?

1. int :- 
Whole Numbers:- -1, -4, 6, 89, 90,

2. float :- 
Decimal Numbers:- 9.5, 100.45, -5.6, -28.9, 0.0 ?

3. bool :-
True/False

4. str:-
"sequence of characters":- all the characters that you see in your keyboard + others as well.

single quotest, double quotes, and triple quotes

support indexing
# ordered in nature

x = "I am learning python"
y = "Abhishek"
z = "Neel Armstrong"

ap = 'I am learning python'
am = 'Abhishek'
an = 'Neel Armstrong'

lk = """I am learning python"""
mk = """Abhishek"""
nk = """Neel Armstrong"""

# %%
# Function to find the data type which is pointed by a variable:-
# type()

# %%
x = 0.0

print(type(x))
# Out:
# <class 'float'>

# %%
x = 0

print(type(x))
# Out:
# <class 'int'>

# %%
is_passed = True

# %%
print(is_passed)
# Out:
# True

# %%
is_passed = False

# %%
print(is_passed)
# Out:
# False

# %%
x = "I am learning python"
y = "Abhishek"
z = "Neel Armstrong"

ap = 'I am learning python'
am = 'Abhishek'
an = 'Neel Armstrong'

lk = """I am learning python"""
mk = """Abhishek"""
nk = """Neel Armstrong"""


print(x, y, z)


print(ap, am, an)


print(lk, mk, nk)
# Out:
# I am learning python Abhishek Neel Armstrong
# I am learning python Abhishek Neel Armstrong
# I am learning python Abhishek Neel Armstrong

# %%
good_string = "You're my best friend"

# %%
print(good_string)
# Out:
# You're my best friend

# %%
bad_string = 'You're my best friend'
# Out:
#   File "<ipython-input-24-78669071bd76>", line 1
#     bad_string = 'You're my best friend'
#                        ^
# SyntaxError: invalid syntax

# %%
good_string = 'You are my "best" friend'

# %%
print(good_string)
# Out:
# You are my "best" friend

# %%
# Data Types continued

# 5. list :- sequence of hetrogenous elements/items/data_type , mutable/changeable, support indexing,
# ordered in nature

# [] square brackets


# 6. tuple:- sequence of hetrogenous elements/items/data_type, immutable/not changeable, support indexing

# () round brackets
# ordered in nature

list_of_fruits = ['apple', 'banana', 'mango', 560, 78.30, True, False, ['kiwi', True, 678], 'pomegranate']


print(list_of_fruits)
# Out:
# ['apple', 'banana', 'mango', 560, 78.3, True, False, ['kiwi', True, 678], 'pomegranate']

# %%
list_of_fruits[2] = 'orange'

# %%
print(list_of_fruits)
# Out:
# ['apple', 'banana', 'orange', 560, 78.3, True, False, ['kiwi', True, 678], 'pomegranate']

# %%
# Indexing

Points to the position of an item.
Indexing in Python starts from 0.
Negative Indexing starts from -1 which is the last element and grows like -2 for second last element
and so on.

# %%
list_of_fruits = ['apple', 'banana', 'mango', 560, 78.30, True, False, ['kiwi', True, 678], 'pomegranate']

# %%
print(list_of_fruits[0])
# Out:
# apple

# %%
print(list_of_fruits[-1])
# Out:
# pomegranate

# %%
print(list_of_fruits[5])
# Out:
# True

# %%
print(list_of_fruits[7][2])
# Out:
# 678

# %%
print(list_of_fruits[-2])
# Out:
# ['kiwi', True, 678]

# %%
print(list_of_fruits[7][-1])
# Out:
# 678

# %%
list_of_fruits = ['apple', 'banana', 'mango', 560, 78.30, True, False, ['kiwi', True, 678], 'pomegranate']

print(list_of_fruits[-1])
# Out:
# pomegranate

# %%
type(list_of_fruits)
# Out:
# list

# %%
x = 'Python is a high level programming language'

print(x[0])
# Out:
# P

# %%
print(x[2])
# Out:
# t

# %%
print(x[-1])
# Out:
# e

# %%
print(x[-2])
# Out:
# g

# %%
tuple_of_fruits = ('apple', 'banana', 'mango', 560, 78.30, True, False, ['kiwi', True, 678], 'pomegranate')

# %%
type(tuple_of_fruits)
# Out:
# tuple

# %%
tuple_of_fruits[0] = 'orange'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-270bb51f0000> in <module>
# ----> 1 tuple_of_fruits[0] = 'orange'
#
# TypeError: 'tuple' object does not support item assignment

# %%
tuple_of_fruits[0]
# Out:
# 'apple'

# %%
tuple_of_fruits[7]
# Out:
# ['kiwi', True, 678]

# %%
tuple_of_fruits[-1]
# Out:
# 'pomegranate'

# %%
tuple_of_fruits = ('apple', 'banana', 'mango', 560, 78.30, True, False, ['kiwi', True, 678], 'pomegranate')



tuple_of_fruits[7][0] = 'orange'

# %%
print(tuple_of_fruits)
# Out:
# ('apple', 'banana', 'mango', 560, 78.3, True, False, ['orange', True, 678], 'pomegranate')

# %%
tuple_of_fruits[7] = 'orange'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-fbfe04935583> in <module>
# ----> 1 tuple_of_fruits[7] = 'orange'
#
# TypeError: 'tuple' object does not support item assignment

# %%
tuple_of_fruits = ('apple', 'banana', 'mango', 560, 78.30, True, False, ['kiwi', True, 678], 'pomegranate', 'apple')


tuple_of_fruits[7].append(2000)

# %%
print(tuple_of_fruits)
# Out:
# ('apple', 'banana', 'mango', 560, 78.3, True, False, ['kiwi', True, 678, 2000], 'pomegranate', 'apple')

# %%
# 7. dict

# mapping


dictionary_of_python_libraries = {'python': 3.10, 'pandas': 2.5, 'numpy': 3.4}

# key:value
# pair
# mutable in nature
# generally they are unordered in nature, they do not indexing.
# keys are unique, and you can not have duplicate keys like 'python' can not appear twice.
# values can be duplicate


# 8. set

# 9. None

# %%
dictionary_of_python_libraries.keys()
# Out:
# dict_keys(['python', 'pandas', 'numpy'])

# %%
dictionary_of_python_libraries.values()
# Out:
# dict_values([3.1, 2.5, 3.4])

# %%
dictionary_of_python_libraries = {'python': 3.10, 'pandas': 2.5, 'numpy': 3.4, 'python': 3.14}

# %%
print(dictionary_of_python_libraries)
# Out:
# {'python': 3.14, 'pandas': 2.5, 'numpy': 3.4}

# %%
dictionary_of_python_libraries = {'python': 3.10, 'pandas': 2.5, 'numpy': 3.4, 'python': 3.14, 'some_random': 3.14}

# %%
print(dictionary_of_python_libraries)
# Out:
# {'python': 3.14, 'pandas': 2.5, 'numpy': 3.4, 'some_random': 3.14}

# %%
dict are superfast to get a value.

getting any key from dictionary_of_python_libraries is >>> compared to searching a key in a list.


10**7,9

hashing
